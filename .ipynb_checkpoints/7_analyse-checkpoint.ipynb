# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus']=False
sns.set_theme(style='darkgrid')
result = pd.read_csv('result/heart-disease/validity/validity.csv')
result
# Out:
#      Number of removed features  validity score Interpreter Model
# 0                             1          0.1273        SHAP    RF
# 1                             2          0.1091        SHAP    RF
# 2                             3          0.1818        SHAP    RF
# 3                             4          0.2000        SHAP    RF
# 4                             5          0.3818        SHAP    RF
# ..                          ...             ...         ...   ...
# 367                          27          0.7407        LORE   MLP
# 368                          28          0.7407        LORE   MLP
# 369                          29          0.7407        LORE   MLP
# 370                          30          0.7407        LORE   MLP
# 371                          31          0.7407        LORE   MLP
#
# [372 rows x 4 columns]

# %%
g = sns.FacetGrid(result, col='Model', hue="Interpreter")
g.map_dataframe(sns.lineplot, x='Number of removed features', y='validity score')
g.add_legend()

plt.ylim(0, 1)
plt.show()

# %%
g.savefig("result/heart-disease/validity/validity.svg",dpi=400)
